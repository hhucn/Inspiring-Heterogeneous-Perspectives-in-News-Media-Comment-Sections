# %%
# !pip install sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 85 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.0 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 44.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 40.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 42.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126709 sha256=5acb9ec8ec124fe5e8842ae831f821c295b6b6d0758979b160f551c54306ff43
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import torch

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def read_article_from_dataset(filename: str) -> pd.DataFrame:
    return pd.read_csv(filename)[["articleID", "headline", "keywords"]]

# %%
filenames = ["ArticlesMay2017.csv"]

# %%
article_sets = [(filename, read_article_from_dataset("gdrive/MyDrive/Research/NewYorkTimesComments/" + filename)) for filename in filenames]

# %%
len(article_sets)
# Out:
# 1

# %%
model = SentenceTransformer('paraphrase-mpnet-base-v2')

# %%
from tqdm import tqdm

def compute_embeddings(articles):
  embeddings = []

  for article in tqdm(articles.itertuples()):
        embedding = model.encode(article.keywords, convert_to_tensor=True)
        embeddings.append({"ID": article.articleID,
                          "headline": article.headline,
                          "keywords": article.keywords,
                          "embedding": embedding})
  return embeddings

# %%
for article in article_sets:
  embeddings = compute_embeddings(article[1])
  torch.save(embeddings, "gdrive/MyDrive/Research/embedded_article_" + article[0].split(".")[0] + "_paraphrase-mpnet-base-v2.pt")
# Out:
# 996it [03:04,  5.38it/s]
